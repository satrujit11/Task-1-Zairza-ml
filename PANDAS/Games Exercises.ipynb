# %% [markdown]
# # PANDAS
# This exercise is for you to practice your pandas skills! We will be using the [Games](https://www.kaggle.com/gutsyrobot/games-data/data) Dataset from Kaggle!.

# %% [markdown]
# #### Import pandas and read in the Games csv file and set it to a DataFrame called gms

# %%
# your code here-
import pandas as pd
gms = pd.read_csv('games.csv')

# %% [markdown]
# #### Check the head of the DataFrame.

# %%
# your code here-
gms.head()
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# 1        150.0    12.0        14383         8.28798               8.14232
# 2        210.0    12.0         9262         8.28994               8.06886
# 3        240.0    12.0        13294         8.20407               8.05804
# 4        150.0    12.0        39883         8.14261               8.04524
#
#    total_owners  total_traders  total_wanters  total_wishers  total_comments  \
# 0         26647            372           1219           5865            5347
# 1         16519            132           1586           6277            2526
# 2         12230             99           1476           5600            1700
# 3         14343            362           1084           5075            3378
# 4         44362            795            861           5414            9173
#
#    total_weights  average_weight
# 0           2562          3.4785
# 1           1423          3.8939
# 2            777          3.7761
# 3           1642          4.1590
# 4           5213          3.2943

# %% [markdown]
# ####  Use .info() method to find out total number of entries in dataset

# %%
# your code here-
gms.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81312 entries, 0 to 81311
# Columns: 20 entries, id to average_weight
# dtypes: float64(10), int64(8), object(2)
# memory usage: 12.4+ MB

# %% [markdown]
# #### How many rows and columns are present in the dataset?

# %%
# your code here-
gms.shape
# Out:
# (81312, 20)

# %% [markdown]
# #### What is the highest number of comments received for a game?

# %%
# your code here-
gms['total_comments'].max()
# Out:
# 11798

# %% [markdown]
# #### What is the name of the game with id 1500?

# %%
# your code here-
gms[gms['id']==1500].name.tolist()
# Out:
# ['Zocken']

# %% [markdown]
# #### Which games have received the least number of comments?

# %%
# your code here-
pd.DataFrame(gms[gms['total_comments']== gms['total_comments'].min()].name.tolist())
# Out:
#                                                        0
# 0                                             Looney Leo
# 1                                                   Dump
# 2                                          Field of Fire
# 3                                               Matheeno
# 4      Auction America: The Trivia Game for Any Colle...
# ...                                                  ...
# 28996                               Micro Rome: Aegyptus
# 28997  Trivial Pursuit: Marvel Cinematic Universe  Da...
# 28998                                          BEARanoia
# 28999                                            Freight
# 29000                                  Bingo Animal Kids
#
# [29001 rows x 1 columns]

# %% [markdown]
# #### Which games have received the highest number of comments?¶

# %%
# your code here-
gms[gms['total_comments']== gms['total_comments'].max()].name.tolist()
# Out:
# ['Catan', 'Catan']

# %% [markdown]
# #### How many unique games are there in the dataset?

# %%
# your code here-
gms['name'].nunique()
# Out:
# 76035

# %% [markdown]
# #### How many boardgames and boardgameexpansions are there in the dataset?

# %%
# your code here-
pd.DataFrame(gms['type'].value_counts())
# Out:
#                      type
# boardgame           70820
# boardgameexpansion  10492

# %% [markdown]
# #### What is the mean playin time for all games put together ?

# %%
# your code here-
gms['playingtime'].mean()
# Out:
# 51.63478827682052

# %% [markdown]
# #### Is there a correlation between playing time and total comments for the games? hint:- Use the .corr() function

# %%
# your code here-
gms['playingtime'].corr(gms['total_comments'])
# Out:
# 0.020645113746224596

# %% [markdown]
# # KEEP UP THE GOOD WORK!!!
